# %%
a=10
a
print(a)
a
b=9
# Out:
# 10

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
s="Hello World"
s
print(type(s))
s
# Out:
# <class 'str'>
# 'Hello World'

# %%
if 1>2 : 
    print("Hello") 
    print("Hello")
    print("Hello") 
elif 1==1 :
    print("Hi")
else : 
    print("World")
# Out:
# Hi
