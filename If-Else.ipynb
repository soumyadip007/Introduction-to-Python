# %% [markdown]
# ### If, Elif, Else Statements

# %%
if 1 < 2:
    print('Yep!')
# Out:
# Yep!

# %%
if 1 < 2:
    print('yep!')
# Out:
# yep!

# %%
if 1 < 2:
    print('first')
else:
    print('last')
# Out:
# first

# %%
p
# Out:
# last

# %%
if 2 == 2:
    print('first')
elif 3 == 3:
    print('middle')
else:
    print('Last')
# Out:
# first
